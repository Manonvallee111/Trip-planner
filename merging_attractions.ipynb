# %%
import requests
import json

# %%
api_endpoint = "https://maps.googleapis.com/maps/api/place/textsearch/json"
base_url = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
API_KEY = 'AIzaSyBuEH6ka2tFVp4P3zP6r5DRBoBQdTIpYOI'

# %%
country = input("Enter a country or city name: ")
# Out:
# Enter a country or city name: madrid

# %% [markdown]
# # Natural features

# %%
def get_natural_feature(country):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    querystring = {"query": "natural feature in " + country, "key": API_KEY}
    response = requests.request("GET", url, params=querystring)
    data = json.loads(response.text)
    locations = []

    if data['status'] == 'OK':
        results = data['results']
        for result in results:
            name = result['name']
            location = result['geometry']['location']
            lat = location['lat']
            lng = location['lng']
           
            locations.extend([name,(lat,lng)])
            

    else:
            return("Error:", data['status'])
    return locations

# %%
info = get_natural_feature(country)

# %%
def Convert(lst):
    res_dct = {lst[i]: lst[i + 1] for i in range(0, len(lst), 2)}
    return res_dct

# %%
Convert(info)
# Out:
# {'Berlin Park': (40.4504072, -3.675755799999999),
#  'Casa de Campo Lake': (40.4187716, -3.7326261),
#  'La Montaña Park': (40.4229964, -3.716896),
#  'Great Pond of El Retiro': (40.417142, -3.6839005),
#  'Manzanares River Linear Park': (40.3775309, -3.6865892),
#  'El Retiro Park': (40.4152606, -3.6844995),
#  'Countryside House Park': (40.4252589, -3.7526816),
#  "Park plantation of the Berro's fountain": (40.4215611, -3.660819699999999),
#  'Jardín El Capricho de la Alameda de Osuna': (40.4558582, -3.599150899999999),
#  'Parque Forestal de Valdebebas - Felipe VI': (40.4909787, -3.6338581),
#  'Sabatini Garden': (40.42033199999999, -3.7140039),
#  'Cecilio Rodríguez Pavilion': (40.4124509, -3.6777427),
#  'Rosaleda del Parque del Oeste': (40.4264992, -3.7219103),
#  'Rose Garden': (40.41079010000001, -3.6803226),
#  "El Pardo's Dam": (40.5387583, -3.7886219),
#  'Monte de El Pardo': (40.53638890000001, -3.8025),
#  'Cecilio Rodríguez Garden': (40.4133196, -3.6779997),
#  'Las Cruces Park': (40.377719, -3.7589181),
#  'Toledo Bridge': (40.3996515, -3.7149353),
#  'Royal Palace of Madrid': (40.417955, -3.714311999999999)}

# %% [markdown]
# # Famous landmarks

# %%
query = f'{country} landmarks'
params = {
    'query': query,
    'key': 'AIzaSyBuEH6ka2tFVp4P3zP6r5DRBoBQdTIpYOI'
}

# %%
response = requests.get(base_url, params=params)
data = response.json()

# %%
results = sorted(data['results'], key=lambda x: x['user_ratings_total'], reverse=True)
locations = []

# %%
results
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. Mayor, 28012 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.415511, 'lng': -3.7074009},
#    'viewport': {'northeast': {'lat': 40.41696072989272,
#      'lng': -3.705867649999998},
#     'southwest': {'lat': 40.41426107010728, 'lng': -3.70892745}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Plaza Mayor',
#   'photos': [{'height': 3472,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107955470253538953548">wen-chih kao chiu</a>'],
#     'photo_reference': 'AfLeUgM6FZZxZ7wsJ9KbpKb6f9lTr3UWJ_hUST51UBQDzGPOnucUjZXaaH21iZq_4pGc02afhMRX5wm4FaI3avh04R5nek7Yz-IdmJVkZQ-YEpAPH4xiO8ZQNyLlmJ3FRpvkj_4_D59xhIp5Tu7-weP5F68JL2aXw7TI67EtCYor9TF13YQc',
#     'width': 4640}],
#   'place_id': 'ChIJZX56134oQg0RHBgRAVQ8pkk',
#   'plus_code': {'compound_code': 'C78V+62 Madrid, Spain',
#    'global_code': '8CGRC78V+62'},
#   'rating': 4.6,
#   'reference': 'ChIJZX56134oQg0RHBgRAVQ8pkk',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 156592},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. de España, 28008 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4233828, 'lng': -3.7121647},
#    'viewport': {'northeast': {'lat': 40.42469117989272,
#      'lng': -3.710991170107278},
#     'southwest': {'lat': 40.42199152010728, 'lng': -3.713690829892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Plaza de España',
#   'photos': [{'height': 438,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105190253154347817269">A Google User</a>'],
#     'photo_reference': 'AfLeUgOh8RMjNWmPvusk39Jvh3yeI-zdSav2wIgk8zNroQyb9BGOk1GtDP7KTP08NLEGUHAVzReMGw1jj6XEhMlJ4TUwZF4GowksvUFYauDhZf79KBP8JVvmQpr_nCik3xhTW7eTWS4cYWyOI6emJCIfSnHIDACLkwg7VuypJujHeVpkxUMH',
#     'width': 612}],
#   'place_id': 'ChIJGXD3s3ooQg0RnfW6WsALwFY',
#   'plus_code': {'compound_code': 'C7FQ+94 Madrid, Spain',
#    'global_code': '8CGRC7FQ+94'},
#   'rating': 4.4,
#   'reference': 'ChIJGXD3s3ooQg0RnfW6WsALwFY',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 102113},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Bailén, s/n, 28071 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.417955, 'lng': -3.714311999999999},
#    'viewport': {'northeast': {'lat': 40.41884912989272,
#      'lng': -3.712398470107277},
#     'southwest': {'lat': 40.41614947010728, 'lng': -3.715098129892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Royal Palace of Madrid',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 6221,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116936815557255163303">A Google User</a>'],
#     'photo_reference': 'AfLeUgNzQtKyqcEZ2L694wD6QCB3-z-0XQYHLE-T43meJknZ-jCEJy_Vu0GetLd8ZKUKkvA-vchGX7cnctLGXoPvRua5bARvNRfkBM_v1lcicWZ11FK1gLAzJy0s45eYPK0W9XBa1To4JuduRd976X0uR3OGcFb5FHnET0HCi0ah_B91oj4x',
#     'width': 9332}],
#   'place_id': 'ChIJwamkfX4oQg0RUUjO1nnsfy4',
#   'plus_code': {'compound_code': 'C79P+57 Madrid, Spain',
#    'global_code': '8CGRC79P+57'},
#   'rating': 4.6,
#   'reference': 'ChIJwamkfX4oQg0RUUjO1nnsfy4',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 81759},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'P.º de la Prta del Ángel, 1, 28011 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4252589, 'lng': -3.7526816},
#    'viewport': {'northeast': {'lat': 40.42683792989271,
#      'lng': -3.751761570107278},
#     'southwest': {'lat': 40.42413827010727, 'lng': -3.754461229892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png',
#   'icon_background_color': '#4DB546',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet',
#   'name': 'Countryside House Park',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 335,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100926479920701320278">Carlos Ogallar</a>'],
#     'photo_reference': 'AfLeUgML4ahkI59CoKupc83Hekj2zWQcCWlqNBermUfusETmvSmMO_LnXAm_vO3mNMw7ROgL99aspT_ppyu_yQwM6ZrEVo4fSJONQv3seBYjQylDdz116lgAyr6uSNIXBLVlwgOGqj5LxifPR8ELME99wI75lmikrfR9P5oBpfgveRfz2ifz',
#     'width': 660}],
#   'place_id': 'ChIJtRbzP-2HQQ0RJx9XvRW6qLw',
#   'plus_code': {'compound_code': 'C6GW+4W Madrid, Spain',
#    'global_code': '8CGRC6GW+4W'},
#   'rating': 4.5,
#   'reference': 'ChIJtRbzP-2HQQ0RJx9XvRW6qLw',
#   'types': ['park',
#    'tourist_attraction',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 46988},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Ferraz, 1, 28008 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4240216, 'lng': -3.717769499999999},
#    'viewport': {'northeast': {'lat': 40.42611839999999, 'lng': -3.71437915},
#     'southwest': {'lat': 40.422768, 'lng': -3.72110655}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/monument_pinlet',
#   'name': 'Temple of Debod',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101365743311249215231">Elisabetta Borzini</a>'],
#     'photo_reference': 'AfLeUgNxYntz4ncFQYg2gUbDyb07CzxaHtu7wjwV6Z_s4sIrCP6XCQst_zNDHvbes-A3yCkrn24z2WfeRcAQormwstDqTAMVSWq-Msvf0d_FM5kgGN0SUuiX_pfZgRTEzlaNszWfutV_HkNq8QY5QKZO2OSwzMkbbbWwghq3fHorUj80XnV-',
#     'width': 3024}],
#   'place_id': 'ChIJWRLqi24oQg0RqwZ3SsbZah0',
#   'plus_code': {'compound_code': 'C7FJ+JV Madrid, Spain',
#    'global_code': '8CGRC7FJ+JV'},
#   'rating': 4.4,
#   'reference': 'ChIJWRLqi24oQg0RqwZ3SsbZah0',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 46214},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. de la Independencia, s/n, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.419992, 'lng': -3.688737},
#    'viewport': {'northeast': {'lat': 40.42135277989272,
#      'lng': -3.687535870107279},
#     'southwest': {'lat': 40.41865312010728, 'lng': -3.690235529892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/monument_pinlet',
#   'name': 'Puerta de Alcalá',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3472,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114685376961399713487">Antonio Mencia</a>'],
#     'photo_reference': 'AfLeUgN37LFnB7T4rOnfFt40-hKXF25ov8VFJs9LUlFo9jT2Ra1C_nwT9ZtTYMqGdkAhjhvugZzQfTHT5vpM-5f5fQKX2nDGgQD9HnTB0DC4H3nilNxON9-lDJm2wfS-P_lzaHNgh-C8P2k3Q0KjKp2v43MjRUoUneCaUPFH7TN_IMhmfZss',
#     'width': 4624}],
#   'place_id': 'ChIJJ1KGSpooQg0R8YZKFDqLJ5g',
#   'plus_code': {'compound_code': 'C896+XG Madrid, Spain',
#    'global_code': '8CGRC896+XG'},
#   'rating': 4.7,
#   'reference': 'ChIJJ1KGSpooQg0R8YZKFDqLJ5g',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 44925},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'P.º de Cuba, 4, 28009 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4136266, 'lng': -3.6820397},
#    'viewport': {'northeast': {'lat': 40.42138954999999, 'lng': -3.67749275},
#     'southwest': {'lat': 40.41103895000001, 'lng': -3.683555349999999}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/museum_pinlet',
#   'name': 'Palacio de Cristal',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106257981604511956981">Froilán Martínez</a>'],
#     'photo_reference': 'AfLeUgM_Hp18IJewuBv7I1AGUblkLyeanqNI9imVq8YEOk5Y36jtREYUybhfaSUaQ4InuAryOMFxnjwbCQo0eft042rzwiLJS4HB7PGam0jOwR3w5Lwj8JEnYHA_QJ41ILsf3YVNfGCInGMrp8MtR6Jr6AF9Oovgpvffa55bfQmUVmsVL1cu',
#     'width': 4000}],
#   'place_id': 'ChIJmy6-B6AoQg0RWfqNzFXrq3k',
#   'plus_code': {'compound_code': 'C879+F5 Madrid, Spain',
#    'global_code': '8CGRC879+F5'},
#   'rating': 4.6,
#   'reference': 'ChIJmy6-B6AoQg0RWfqNzFXrq3k',
#   'types': ['museum',
#    'tourist_attraction',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 40337},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alcalá, 237, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4321355, 'lng': -3.6632911},
#    'viewport': {'northeast': {'lat': 40.43360739999999,
#      'lng': -3.660381399999999},
#     'southwest': {'lat': 40.43080860000001, 'lng': -3.665735}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Las Ventas Bullring',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 9000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108360417130654505652">Cesar Alfonso Franco</a>'],
#     'photo_reference': 'AfLeUgN-bmCy5RPFTmYn39ZU3WIeKtkS7mZuxZva9kyuyGnsBAs37biFcDeJWBzxI3zJUuvyArjC8pkN2UA9mlHKRzMhqZQJ980DliNoTmWulMz_TQ-40gOs2dHr6dLr1MYAkBaZSKNUrq_i1MysiMi3Xr07XFWWLG5Uj4tvwLqzeAd271vo',
#     'width': 12000}],
#   'place_id': 'ChIJN9Ka0LQoQg0RyKntUElZV74',
#   'plus_code': {'compound_code': 'C8JP+VM Madrid, Spain',
#    'global_code': '8CGRC8JP+VM'},
#   'rating': 4.5,
#   'reference': 'ChIJN9Ka0LQoQg0RyKntUElZV74',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 30121},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Bailén, 10, 28013 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.415651, 'lng': -3.714552},
#    'viewport': {'northeast': {'lat': 40.41708612989272,
#      'lng': -3.712698220107279},
#     'southwest': {'lat': 40.41438647010728, 'lng': -3.715397879892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Catedral de la Almudena',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100499579685312584402">Esmeralda Padilla Valdivia</a>'],
#     'photo_reference': 'AfLeUgOTmmbV_A5kQHneEalpn8OiF0eTmlsjmBWFifgO2ZZuuhOJ8oOF94Su6h13yB2tvYFeGIqLMXlV4QkqzJ0_BRxOWAjUYxpEidTqYsYvS3MeCMQR9SLooHpd0yiHi11JnB8DuIYRc0H13s4jyl44SSBeKDguogBBhHLTqR-sEetdDFeK',
#     'width': 4032}],
#   'place_id': 'ChIJI_FYeHcoQg0RcqwG5gDs3H8',
#   'plus_code': {'compound_code': 'C78P+75 Madrid, Spain',
#    'global_code': '8CGRC78P+75'},
#   'rating': 4.6,
#   'reference': 'ChIJI_FYeHcoQg0RcqwG5gDs3H8',
#   'types': ['tourist_attraction',
#    'church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 20208},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Gta. de la Prta de Toledo, s/n, 28005 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4067666, 'lng': -3.7116145},
#    'viewport': {'northeast': {'lat': 40.40809707989271,
#      'lng': -3.710246570107278},
#     'southwest': {'lat': 40.40539742010727, 'lng': -3.712946229892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/monument_pinlet',
#   'name': 'Toledo Gate',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2961,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111513030161569054266">Cati Mudoy</a>'],
#     'photo_reference': 'AfLeUgOoT1odqgSKLCB8hwLofedFmcbz0QMGm9RGwSLrXoyzmQomrSF1CkEuJMVY3kvlkqsg99ldrLwUjYUAaMXs6di3u7HJmCzkYmuuAkoBq_v9YqXsDP53b-P2BY7cOy-OxAMm4aJmztCa2tuIcpBHtI7PLq1zqefUCowatPXdDQbEXZi4',
#     'width': 2084}],
#   'place_id': 'ChIJTdm0x9AnQg0R2OeiT29EvFQ',
#   'plus_code': {'compound_code': 'C74Q+P9 Madrid, Spain',
#    'global_code': '8CGRC74Q+P9'},
#   'rating': 4.5,
#   'reference': 'ChIJTdm0x9AnQg0R2OeiT29EvFQ',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 14104},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. de Isabel II, s/n, 28013 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.418299, 'lng': -3.710578},
#    'viewport': {'northeast': {'lat': 40.41964882989272,
#      'lng': -3.709228170107278},
#     'southwest': {'lat': 40.41694917010727, 'lng': -3.711927829892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Teatro Real',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3072,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112977357160507793553">Daniel Pratt</a>'],
#     'photo_reference': 'AfLeUgMvU-pRsIG-BPC-f3jrqxiyC6_JcMtRd4zLb0kbYPADRgPha_tuS7GZdf_MK8UbiE2gUo2WkHRQ_WQDUMUu0ZS3oHrukFzWQ4JhEXujNwFpYF-AQn8I03exzfecme391rqpSHSt_Pq8YTMCxKmNYAMZTB9YsVQMDH6KzLsc52kpAG0W',
#     'width': 4080}],
#   'place_id': 'ChIJZY540HsoQg0Rrq2nqutjg6I',
#   'plus_code': {'compound_code': 'C79Q+8Q Madrid, Spain',
#    'global_code': '8CGRC79Q+8Q'},
#   'rating': 4.6,
#   'reference': 'ChIJZY540HsoQg0Rrq2nqutjg6I',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 11307},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Ventura Rodríguez, 17, 28008 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.42378799999999, 'lng': -3.7145977},
#    'viewport': {'northeast': {'lat': 40.42514402989272,
#      'lng': -3.713266870107278},
#     'southwest': {'lat': 40.42244437010727, 'lng': -3.715966529892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/museum_pinlet',
#   'name': 'Cerralbo Museum',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102311898548209811199">Nadia Monteiro</a>'],
#     'photo_reference': 'AfLeUgOb6sFhf6zJntLYrxBLrHe3euncSHROVJvEuItPIO7JqJX2bPdcC2G6G2Nt_HYChxTdqt1fzgua59kNGgFgxh5fnCbt8q6gw2RNPMBSDGvvKNKzsPgtzKUtEOrC3n2h1a4d8DiDWfgy2Q9O9hqZndU6YwRT-eFWTwIHODd4ecFm77wu',
#     'width': 3024}],
#   'place_id': 'ChIJwzjYwG8oQg0RqHNjv78udl0',
#   'plus_code': {'compound_code': 'C7FP+G5 Madrid, Spain',
#    'global_code': '8CGRC7FP+G5'},
#   'rating': 4.6,
#   'reference': 'ChIJwzjYwG8oQg0RqHNjv78udl0',
#   'types': ['museum',
#    'tourist_attraction',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 5818},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. San Buenaventura, 1, 28005 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4104996, 'lng': -3.7145483},
#    'viewport': {'northeast': {'lat': 40.41189077989272,
#      'lng': -3.712916520107277},
#     'southwest': {'lat': 40.40919112010728, 'lng': -3.715616179892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/worship_general-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/worship_christian_pinlet',
#   'name': 'Royal Basilica of Saint Francis the Great',
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102375658075625545246">Tabrez Khan</a>'],
#     'photo_reference': 'AfLeUgNfRre3n7xVImH5cORxIVLXpCtrZ_9j2ntLLDTudpXqnFsURxHG6aalbr5trdTvEkpCf_yqhn430wrnAr72AbHhvGRYzAV7VRmD1BsCTqrxjCaQyuG8x4h22h11NzRpu3oYAgXCUAjXO28LGgiNlHAlXwYf8eX1hpz-XRStczQTd7eX',
#     'width': 3024}],
#   'place_id': 'ChIJCd5rR9gnQg0RUIJOfg7D19Y',
#   'plus_code': {'compound_code': 'C76P+55 Madrid, Spain',
#    'global_code': '8CGRC76P+55'},
#   'rating': 4.7,
#   'reference': 'ChIJCd5rR9gnQg0RUIJOfg7D19Y',
#   'types': ['tourist_attraction',
#    'museum',
#    'church',
#    'place_of_worship',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 5718},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alcalá, 39, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4187105, 'lng': -3.6975524},
#    'viewport': {'northeast': {'lat': 40.41996147989272,
#      'lng': -3.696201670107278},
#     'southwest': {'lat': 40.41726182010727, 'lng': -3.698901329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Metropolis Building',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4624,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105072724760894761548">Martin Bečvář</a>'],
#     'photo_reference': 'AfLeUgMS2a9LRtkpWGKJH9-X2DUjddLmAjIwlgC1JsQY0Mt4HxBDJcMBdO8uBR4lGOn85dZe4x9-yqbOh3RBL2g9qyT3M5RQxp1tDnDI2c0iadWhfUwLVngXQ4j2vhbFVjp0-TbNqVSEwZks-ByGUoz_EYBUNL-fxaP19JwL1FBs56H7q4W6',
#     'width': 3472}],
#   'place_id': 'ChIJKx77DIQoQg0R_gppYNKr4c0',
#   'plus_code': {'compound_code': 'C892+FX Madrid, Spain',
#    'global_code': '8CGRC892+FX'},
#   'rating': 4.7,
#   'reference': 'ChIJKx77DIQoQg0R_gppYNKr4c0',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 4889},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Parque del Retiro, Pl. de la Independencia, s/n, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.417318, 'lng': -3.6830607},
#    'viewport': {'northeast': {'lat': 40.41866782989273,
#      'lng': -3.681710870107278},
#     'southwest': {'lat': 40.41596817010729, 'lng': -3.684410529892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/monument_pinlet',
#   'name': 'Monument to Alfonso XII',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106243611581036427659">Aureliano Costa</a>'],
#     'photo_reference': 'AfLeUgPP-gHsO9BEuFFnVPBl-SvkxcyILmBpczGsSn5Smwm3ifmSX0KmB5yEc2lARxqbe7voL_vvzr-6JdZijOoweILGPB1VFaN27h0xreCc8KzowkkAGEBo2qa_tfYlwRGfxjQ89GL5ZT7bcQCTO0E8NneKlnHNPQ37pviiAU16qGjy8Gle',
#     'width': 3024}],
#   'place_id': 'ChIJXW01Q58oQg0RZxKRxshjULI',
#   'plus_code': {'compound_code': 'C888+WQ Madrid, Spain',
#    'global_code': '8CGRC888+WQ'},
#   'rating': 4.7,
#   'reference': 'ChIJXW01Q58oQg0RZxKRxshjULI',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 2609},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. de Ote., 28013 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4183418, 'lng': -3.7121865},
#    'viewport': {'northeast': {'lat': 40.41969162989272,
#      'lng': -3.710836670107277},
#     'southwest': {'lat': 40.41699197010728, 'lng': -3.713536329892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/museum-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/monument_pinlet',
#   'name': 'Monument to Felipe IV',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114283569818941404464">A Google User</a>'],
#     'photo_reference': 'AfLeUgMAzRs4OvMtDrpQ9Ye5BmWX9RJbZsfi2hWebdn2RFfrAjpbL_tSOPrhyCk2tpCO9PYNLvXSzMtCCeLzOa5CbDElcQ0NBLg85cW00lgMiIZemk9EYQ_a9G_vmHI-5R2yQtHFS7ZsElold0o0CljSUgW3Fl053Zxe0aradrp8wtpEfQCj',
#     'width': 4000}],
#   'place_id': 'ChIJSeKYEHooQg0RxPASfXZ8eto',
#   'plus_code': {'compound_code': 'C79Q+84 Madrid, Spain',
#    'global_code': '8CGRC79Q+84'},
#   'rating': 4.6,
#   'reference': 'ChIJSeKYEHooQg0RxPASfXZ8eto',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 698},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alfonso XII, 1, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.41668310000001, 'lng': -3.6886536},
#    'viewport': {'northeast': {'lat': 40.41803537989272,
#      'lng': -3.687425620107279},
#     'southwest': {'lat': 40.41533572010728, 'lng': -3.690125279892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Spain Gate',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101096972639459457132">A Google User</a>'],
#     'photo_reference': 'AfLeUgMxfPUIWH-O21DNamHq1G45BbH0sBGYdSzK1aplhmnlqhFpu7d037yykI0jdBVA8oMtlije_zmtQ1fypxKxxCPf5p1S3ZEH54292qjl_syY0w4viGQLhNq-brgMMPEx9W0UZUaOPAX3tE-GXpCnRQSnthc3EClS3-w25Rnn4sUaGe2U',
#     'width': 3024}],
#   'place_id': 'ChIJGYoAOZwoQg0R5I1X_G5TtvA',
#   'plus_code': {'compound_code': 'C886+MG Madrid, Spain',
#    'global_code': '8CGRC886+MG'},
#   'rating': 4.6,
#   'reference': 'ChIJGYoAOZwoQg0R5I1X_G5TtvA',
#   'types': ['tourist_attraction',
#    'park',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 577},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. de la Lealtad, 1, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4164469, 'lng': -3.6928918},
#    'viewport': {'northeast': {'lat': 40.41785707989272,
#      'lng': -3.691253470107278},
#     'southwest': {'lat': 40.41515742010728, 'lng': -3.693953129892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Monumento a los Caídos por España',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1589,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109688512838690327063">ALBANO CURIEL</a>'],
#     'photo_reference': 'AfLeUgNlZAjvAG60itl45DFMhnlUQxgPNan9sFfmfyBpfuLLxfacuX6PGzZeX2HlI5Q1Jja3deQFO6uaAFPZAZv4U3EOalwHTqrNRfLikNdpDDrwaqVK460jBx5wdQVJxBKHCzdcGmHj-wvZGZPbl0ZeZ79wW_rWbVPy4yrzq1K18SUWs9zX',
#     'width': 1486}],
#   'place_id': 'ChIJoZCVLYMoQg0Rgzsk0lNxqtw',
#   'plus_code': {'compound_code': 'C884+HR Madrid, Spain',
#    'global_code': '8CGRC884+HR'},
#   'rating': 4.4,
#   'reference': 'ChIJoZCVLYMoQg0Rgzsk0lNxqtw',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 302},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Barceló, 2D, 28004 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4261017, 'lng': -3.7005765},
#    'viewport': {'northeast': {'lat': 40.42760852989273,
#      'lng': -3.699172720107279},
#     'southwest': {'lat': 40.42490887010729, 'lng': -3.701872379892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Fountain of Fame',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3271,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107308978427989564875">Guadalupe Fernandez</a>'],
#     'photo_reference': 'AfLeUgMLv2trj0AWv-O2MfFWOaWae8A7xT95yxOi5alf5_qLW6dvIytiPE4N5q2s47sY5tMSsScTzmiSnc5iQvIBgadoYxFL1tEq6NgihUMCUNaKm8RSvAtrKi6Tvachc4DkGur8Nkrn-7qCLBAX1un3VAY0krzDO6A1rs88y6UvIpzCuP0w',
#     'width': 2617}],
#   'place_id': 'ChIJE14RqYkoQg0R9INS0oH5hLU',
#   'plus_code': {'compound_code': 'C7GX+CQ Madrid, Spain',
#    'global_code': '8CGRC7GX+CQ'},
#   'rating': 4.2,
#   'reference': 'ChIJE14RqYkoQg0R9INS0oH5hLU',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 19},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C/ Gran Vía, 38, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4187763, 'lng': -3.697175},
#    'viewport': {'northeast': {'lat': 40.42004957989273,
#      'lng': -3.696018670107278},
#     'southwest': {'lat': 40.41734992010728, 'lng': -3.698718329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Gran Vía & C de Alcalá',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2304,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115041252519978869626">A Google User</a>'],
#     'photo_reference': 'AfLeUgMRdTzB94HTPbdxvqozFK3JM6MR0TrM-WvTFRGGmaxfG9S0y2lTcAC2ueoYW3DNoTZ_G2rVNFZNNxV1p2f-fH5luZyVflZhga8g7G1nCOG3t5drNeSlgXoTY63BDNV9H57l44Q9qq17qBY5pHe18OjoTI3cLqYiFXaz3XXjVQIQSkq1',
#     'width': 1536}],
#   'place_id': 'ChIJMyrGNyopQg0ReZZtX6VvPTU',
#   'plus_code': {'compound_code': 'C893+G4 Madrid, Spain',
#    'global_code': '8CGRC893+G4'},
#   'rating': 4.8,
#   'reference': 'ChIJMyrGNyopQg0ReZZtX6VvPTU',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 15}]

# %%
for result in results[:60]:
    name = result['name']
    location = result['geometry']['location']
    lat = location['lat']
    lng = location['lng']
    locations.extend([name,(lat,lng)])

# %%
def Convert(lst):
    res_dct = {lst[i]: lst[i + 1] for i in range(0, len(lst), 2)}
    return res_dct

# %%
Convert(locations)
# Out:
# {'Botanical Garden of Curitiba': (-25.4420753, -49.23877040000001),
#  'Museu Oscar Niemeyer': (-25.4101027, -49.2671932),
#  'Parque Tanguá': (-25.3790661, -49.2824233),
#  'Passeio Público': (-25.4253475, -49.2674245),
#  'Bosque Alemão': (-25.4044672, -49.288116),
#  'Bosque Papa João Paulo II': (-25.4088098, -49.2702598),
#  'Ruínas de São Francisco': (-25.4270475, -49.2756767),
#  'the Polish Immigration Memorial': (-25.4089001, -49.2701858),
#  'Palácio Avenida': (-25.432299, -49.2738032),
#  'Arabic Memorial': (-25.4233867, -49.2683595),
#  'Chaminé Sul - Parque Passaúna': (-25.481806, -49.3802495),
#  'Ground Zero Curitiba': (-25.4293179, -49.2718513),
#  'Obelisk Erasto Gaertner': (-25.4050705, -49.24562539999999),
#  'Largo Júlio Szymanski': (-25.4510385, -49.26276),
#  'Largo Pedro Deconto': (-25.4268041, -49.2992198),
#  'Estátua de São Francisco de Assis': (-25.5066182, -49.3241065),
#  'PEDRA MALEDETA': (-25.4036978, -49.32927540000001),
#  'Tábuas': (-25.4394307, -49.2360104),
#  'Calçada Histórica': (-25.4298309, -49.2719798),
#  'O Ipê mais bonito de Curitiba': (-25.4311036, -49.2439449)}

# %% [markdown]
# # National parks

# %%
def get_national_parks(country):
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    querystring = {"query": "national park in " + country, "key": API_KEY}
    response = requests.request("GET", url, params=querystring)
    data = json.loads(response.text)
    locations = []

    if data['status'] == 'OK':
        results = data['results']
        for result in results:
            name = result['name']
            location = result['geometry']['location']
            lat = location['lat']
            lng = location['lng']
            locations.extend([name,(lat,lng)])

    else:
        return("Error:", data['status'])

    return locations

# %%
infos = get_national_parks(country)

# %%
def Convert(lst):
    res_dct = {lst[i]: lst[i + 1] for i in range(0, len(lst), 2)}
    return res_dct

# %%
Convert(infos)
# Out:
# {'Bosque Zaninelli': (-25.3984171, -49.2824053),
#  'Bosque Armando Ferreira': (-25.4390214, -49.2249566),
#  'Tingui Park': (-25.4023422, -49.3048504),
#  'Parque Tanguá': (-25.3790661, -49.2824233),
#  'Parque Lago Azul': (-25.5743257, -49.2677916),
#  'Kortirion': (-25.4387691, -49.2508546),
#  'Parque Vista Alegre das Mercês': (-25.402313, -49.294895),
#  'Passeio Público': (-25.4253475, -49.2674245),
#  'Bosque Alemão': (-25.4044672, -49.288116),
#  'Mercado Florestal': (-25.3974193, -49.2671572),
#  'Parque Barigui': (-25.4267589, -49.3073152),
#  'Iguaçu Park': (-25.5252249, -49.222599),
#  'Botanical Garden of Curitiba': (-25.4420753, -49.23877040000001),
#  'Parque Tingui': (-25.3939901, -49.3062266),
#  'Bosque de Portugal': (-25.4159596, -49.2320397),
#  'Jardim das Sensações - Jardim Botânico': (-25.4412676, -49.2379831),
#  'Parque Nacional Guaricana': (-25.7127968, -48.8609825),
#  'Serra da Baitaca': (-25.3883333, -49.0025),
#  'Campos Gerais National Park': (-25.0308282, -50.05881180000001),
#  'Pico do Marumbi State Park': (-25.4454019, -48.916372)}

# %%
print(infos)
# Out:
# ['Bosque Zaninelli', (-25.3984171, -49.2824053), 'Bosque Armando Ferreira', (-25.4390214, -49.2249566), 'Tingui Park', (-25.4023422, -49.3048504), 'Parque Tanguá', (-25.3790661, -49.2824233), 'Parque Lago Azul', (-25.5743257, -49.2677916), 'Kortirion', (-25.4387691, -49.2508546), 'Parque Vista Alegre das Mercês', (-25.402313, -49.294895), 'Passeio Público', (-25.4253475, -49.2674245), 'Bosque Alemão', (-25.4044672, -49.288116), 'Mercado Florestal', (-25.3974193, -49.2671572), 'Parque Barigui', (-25.4267589, -49.3073152), 'Iguaçu Park', (-25.5252249, -49.222599), 'Botanical Garden of Curitiba', (-25.4420753, -49.23877040000001), 'Parque Tingui', (-25.3939901, -49.3062266), 'Bosque de Portugal', (-25.4159596, -49.2320397), 'Jardim das Sensações - Jardim Botânico', (-25.4412676, -49.2379831), 'Parque Nacional Guaricana', (-25.7127968, -48.8609825), 'Serra da Baitaca', (-25.3883333, -49.0025), 'Campos Gerais National Park', (-25.0308282, -50.05881180000001), 'Pico do Marumbi State Park', (-25.4454019, -48.916372)]

# %% [markdown]
# # Tourist attractions

# %%
from geopy.geocoders import Nominatim
address= country
geolocator = Nominatim(user_agent="Your_Name")
geolocation = geolocator.geocode(address)
lat= geolocation.latitude
long= geolocation.longitude

# %%
params = {
    "location": country,
    "types": "tourist_attraction",
    "key": API_KEY,
}

# %%
API_KEY = 'AIzaSyBuEH6ka2tFVp4P3zP6r5DRBoBQdTIpYOI'
BASE_URL2 = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{long}&radius=50000&types=tourist_attraction&key=AIzaSyBuEH6ka2tFVp4P3zP6r5DRBoBQdTIpYOI"

# %%
response = requests.get(BASE_URL2, params=params)
response_json = json.loads(response.text)
location1 = []

# %%
sort_rating_ignoring_unrated = sorted([a for a in response_json['results'] if 'rating' in a], key=lambda x: x['rating'], reverse=True)
sorted_rating= sorted(sort_rating_ignoring_unrated, key=lambda x: x['rating'], reverse=True)

for result in sorted_rating:
    name = result["name"]
    rating = result.get("rating", "not available")
    place_type = result["types"][0]
    location = result['geometry']['location']
    lat = location['lat']
    lng = location['lng']
    locations.extend([name,(lat,lng)])
 
    if place_type == "tourist_attraction":
        location1.extend([name,(lat,lng)])

# %%
location1
# Out:
# ['Sanctuary of Our Lady of Perpetual Help',
#  (-25.4207416, -49.26155319999999),
#  'Paróquia São Vicente de Paulo',
#  (-25.4249782, -49.27904270000001),
#  'Parish San Francisco de Paula',
#  (-25.43342790000001, -49.2836418),
#  'SESC Palace of Liberty',
#  (-25.42962, -49.2698931),
#  'Railway Museum',
#  (-25.437499, -49.26579599999999),
#  'Curitiba City Market',
#  (-25.4348279, -49.2569791),
#  'Passeio Público',
#  (-25.4253475, -49.2674245),
#  'Casa Romário Martins',
#  (-25.427762, -49.271933),
#  'Our Lady of Salette Square',
#  (-25.4143801, -49.2682651),
#  'Praça Ouvidor Pardinho',
#  (-25.4436882, -49.27189799999999),
#  'Arabic Memorial',
#  (-25.4233407, -49.2684216),
#  'Ground Zero Curitiba',
#  (-25.4293179, -49.2718513),
#  'Rua 24 Horas',
#  (-25.4347686, -49.2764537)]

# %%
def Convert(lst):
    res_dct = {lst[i]: lst[i + 1] for i in range(0, len(lst), 2)}
    return res_dct

# %%
Convert(location1)
# Out:
# {'Sanctuary of Our Lady of Perpetual Help': (-25.4207416, -49.26155319999999),
#  'Paróquia São Vicente de Paulo': (-25.4249782, -49.27904270000001),
#  'Parish San Francisco de Paula': (-25.43342790000001, -49.2836418),
#  'SESC Palace of Liberty': (-25.42962, -49.2698931),
#  'Railway Museum': (-25.437499, -49.26579599999999),
#  'Curitiba City Market': (-25.4348279, -49.2569791),
#  'Passeio Público': (-25.4253475, -49.2674245),
#  'Casa Romário Martins': (-25.427762, -49.271933),
#  'Our Lady of Salette Square': (-25.4143801, -49.2682651),
#  'Praça Ouvidor Pardinho': (-25.4436882, -49.27189799999999),
#  'Arabic Memorial': (-25.4233407, -49.2684216),
#  'Ground Zero Curitiba': (-25.4293179, -49.2718513),
#  'Rua 24 Horas': (-25.4347686, -49.2764537)}

# %% [markdown]
# # Merging

# %%
merged = Convert(infos) | Convert(locations) | Convert(info) | Convert(location1)

# %%
merged
# Out:
# {'Bosque Zaninelli': (-25.3984171, -49.2824053),
#  'Bosque Armando Ferreira': (-25.4390214, -49.2249566),
#  'Tingui Park': (-25.4023422, -49.3048504),
#  'Parque Tanguá': (-25.3790661, -49.2824233),
#  'Parque Lago Azul': (-25.5743257, -49.2677916),
#  'Kortirion': (-25.4387691, -49.2508546),
#  'Parque Vista Alegre das Mercês': (-25.402313, -49.294895),
#  'Passeio Público': (-25.4253475, -49.2674245),
#  'Bosque Alemão': (-25.4044672, -49.288116),
#  'Mercado Florestal': (-25.3974193, -49.2671572),
#  'Parque Barigui': (-25.4252682, -49.3115807),
#  'Iguaçu Park': (-25.5252249, -49.222599),
#  'Botanical Garden of Curitiba': (-25.4420753, -49.23877040000001),
#  'Parque Tingui': (-25.3939901, -49.3062266),
#  'Bosque de Portugal': (-25.4159596, -49.2320397),
#  'Jardim das Sensações - Jardim Botânico': (-25.4412676, -49.2379831),
#  'Parque Nacional Guaricana': (-25.7127968, -48.8609825),
#  'Serra da Baitaca': (-25.3883333, -49.0025),
#  'Campos Gerais National Park': (-25.0308282, -50.05881180000001),
#  'Pico do Marumbi State Park': (-25.4454019, -48.916372),
#  'Museu Oscar Niemeyer': (-25.4101027, -49.2671932),
#  'Bosque Papa João Paulo II': (-25.4088098, -49.2702598),
#  'Ruínas de São Francisco': (-25.4270475, -49.2756767),
#  'the Polish Immigration Memorial': (-25.4089001, -49.2701858),
#  'Palácio Avenida': (-25.432299, -49.2738032),
#  'Arabic Memorial': (-25.4233407, -49.2684216),
#  'Chaminé Sul - Parque Passaúna': (-25.481806, -49.3802495),
#  'Ground Zero Curitiba': (-25.4293179, -49.2718513),
#  'Obelisk Erasto Gaertner': (-25.4050705, -49.24562539999999),
#  'Largo Júlio Szymanski': (-25.4510385, -49.26276),
#  'Largo Pedro Deconto': (-25.4268041, -49.2992198),
#  'Estátua de São Francisco de Assis': (-25.5066182, -49.3241065),
#  'PEDRA MALEDETA': (-25.4036978, -49.32927540000001),
#  'Tábuas': (-25.4394307, -49.2360104),
#  'Calçada Histórica': (-25.4298309, -49.2719798),
#  'O Ipê mais bonito de Curitiba': (-25.4311036, -49.2439449),
#  'Sanctuary of Our Lady of Perpetual Help': (-25.4207416, -49.26155319999999),
#  'Paróquia São Vicente de Paulo': (-25.4249782, -49.27904270000001),
#  'Museu Paranaense': (-25.4275677, -49.27619779999999),
#  'Parish San Francisco de Paula': (-25.43342790000001, -49.2836418),
#  'Museu do Expedicionário': (-25.4286158, -49.25849660000001),
#  'SESC Palace of Liberty': (-25.42962, -49.2698931),
#  'Railway Museum': (-25.437499, -49.26579599999999),
#  'Alfredo Andersen House Museum': (-25.4246917, -49.2711722),
#  'Museu de Arte - MUSA UFPR': (-25.4293568, -49.2674203),
#  'Curitiba City Market': (-25.4348279, -49.2569791),
#  'Museum of Image and Sound': (-25.4332124, -49.26768819999999),
#  'Casa Romário Martins': (-25.427762, -49.271933),
#  'Praça Oswaldo Cruz': (-25.44051859999999, -49.27603329999999),
#  'Our Lady of Salette Square': (-25.4143801, -49.2682651),
#  'Praça Ouvidor Pardinho': (-25.4436882, -49.27189799999999),
#  'Rua 24 Horas': (-25.4347686, -49.2764537),
#  'Bosque da Fazendinha': (-25.4752118, -49.3225108),
#  'Parque Bosque do Trabalhador': (-25.5102981, -49.31546789999999),
#  'Parque Iguaçu': (-25.5475719, -49.2296697),
#  'Lago Bacacheri': (-25.390882, -49.2299862),
#  'Lago Azul': (-25.5723691, -49.2698863),
#  'Passa Una River': (-25.444237, -49.3868042),
#  'Arroio do Prensa': (-25.5768015, -49.30689810000001),
#  'Rio do Moinho': (-25.5881565, -49.2699809),
#  'Arroio do Espigão': (-25.5874166, -49.279697),
#  'Lago da universidade Positivo': (-25.4492797, -49.3573829),
#  'Rio Barigui': (-25.4818201, -49.3358796),
#  'Rio Belém': (-25.4696459, -49.2472655)}
